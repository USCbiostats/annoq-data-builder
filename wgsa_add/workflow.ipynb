# %% [markdown]
# # Adding Enhancers to AnnoQ
#
# ## Loading data as it is and formatting it accordingly
# Adding and renaming columns headers and setting index for lookups and table joins

# %%
# %ls
# Out:
# TOPMed.sbatch*             dbSNP.sbatch*         output/
# __pycache__/               gunzip.sbatch.sh*     run_jobs.sh*
# add_annotations.py*        gz.sbatch*            slurm/
# add_enhancer_anno.py*      hrc.sbatch*           unzip-input.sbatch*
# add_enhancer_anno_old.py*  hrc_add.sh*           unzip-input.sh*
# add_panther_anno-old.py*   hrc_add_all.sh*       unzip.template.sbatch*
# add_panther_anno.py*       hrc_add_enhancer.sh*  utils.py*
# base.py*                   hrc_batch.template*   workflow.ipynb*
# config/                    hrc_enhancer.sbatch*
# create_sbatch.py*          hrc_sample.sbatch*

# %%
import pandas as pd
import json

enhs =  pd.read_csv("../resources/test/CREbedDBenhancers_10092018", sep='\t', 
                    names=["chr", "start", "end", "enhancer"],
                    index_col="enhancer")
enh_gene_links =pd.read_csv("../resources/test/enh_gene_link_tissue_pval_snp_hg19-sample", sep='\t',
                    dtype={'enhancer':str})
enh_source = pd.read_csv("../resources/test/PEREGRINEenhancersources", sep='\t',
                    names=["enhancer", "source"],                    
                    index_col="enhancer")
tissues = pd.read_csv("../resources/test/tissues.txt", sep='\t')
assays = pd.read_csv("../resources/test/assaytable.txt",  sep='\t',
                    names=["id", "assay_label"],
                    index_col="id")

# %% [markdown]
# ## Mapping tissues to more friendly headers
# for future when we need tissues

# %%
 fields = [
        "tissue_id",
        "tissue_name",
        "tissue_source",
        "tissue_external_id",
        "tissue_organ_and_tissue",
        "tissue_cell_type",
        "tissue_disease",
        "tissue_sample",
        "tissue_brenda_tissue_ontology",
        "tissue_brenda_term",
        "tissue_url"
    ]
    
tissues.columns=fields
tissues.set_index('tissue_id', inplace=True)

# %% [markdown]
# ## Some Stats for our data

# %%
enh_gene_links.shape
# Out:
# (9999, 7)

# %% [markdown]
# ## Left join the table
# - enhancer detail
# - enhancer source
# - ttissue is
# - asssay id

# %%
agg_table = enh_gene_links.merge(enhs, how="left", left_on="enhancer", right_on="enhancer")
agg_table = agg_table.merge(tissues, how="left", left_on="tissue", right_on="tissue_id")
agg_table = agg_table.merge(assays, how="left", left_on="assay", right_on="id")
agg_table = agg_table.merge(enh_source, how="left", left_on="enhancer", right_on="enhancer")
agg_table
# Out:
#      enhancer                               gene  linkID  assay  tissue  \
# 0           1  HUMAN|HGNC=15846|UniProtKB=Q9NP74       1      3      64
# 1           1  HUMAN|HGNC=15846|UniProtKB=Q9NP74       1      3      65
# 2           1  HUMAN|HGNC=15846|UniProtKB=Q9NP74       1      3      66
# 3           1  HUMAN|HGNC=15846|UniProtKB=Q9NP74       1      3      67
# 4           1  HUMAN|HGNC=15846|UniProtKB=Q9NP74       1      3      68
# ...       ...                                ...     ...    ...     ...
# 9994    10730  HUMAN|HGNC=24836|UniProtKB=Q6ZVL6     530      3      74
# 9995    10730  HUMAN|HGNC=24836|UniProtKB=Q6ZVL6     530      3      75
# 9996    10730  HUMAN|HGNC=24836|UniProtKB=Q6ZVL6     530      3      76
# 9997    10730  HUMAN|HGNC=24836|UniProtKB=Q6ZVL6     530      3      77
# 9998    10730  HUMAN|HGNC=24836|UniProtKB=Q6ZVL6     530      3      78
#
#       p-value eQTL_SNP_ID    chr      start        end  ...  \
# 0         NaN         NaN   chr1  100000188  100000393  ...
# 1         NaN         NaN   chr1  100000188  100000393  ...
# 2         NaN         NaN   chr1  100000188  100000393  ...
# 3         NaN         NaN   chr1  100000188  100000393  ...
# 4         NaN         NaN   chr1  100000188  100000393  ...
# ...       ...         ...    ...        ...        ...  ...
# 9994      NaN         NaN  chr11   33708893   33709097  ...
# 9995      NaN         NaN  chr11   33708893   33709097  ...
# 9996      NaN         NaN  chr11   33708893   33709097  ...
# 9997      NaN         NaN  chr11   33708893   33709097  ...
# 9998      NaN         NaN  chr11   33708893   33709097  ...
#
#      tissue_external_id tissue_organ_and_tissue tissue_cell_type  \
# 0               CCL-185                    Lung       epithelial
# 1                HTB-47                  Kidney       epithelial
# 2              CRL-1441                  Kidney       epithelial
# 3              CRL-1740                Prostate       epithelial
# 4               HTB-177                    Lung       epithelial
# ...                 ...                     ...              ...
# 9994             HTB-10                   Brain       epithelial
# 9995            HTB-133           Mammary gland       epithelial
# 9996           CRL-1611                  Kidney       epithelial
# 9997            CCL-221                   Colon       epithelial
# 9998        ENCSR011GNI              Cerebellum        astrocyte
#
#                  tissue_disease tissue_sample tissue_brenda_tissue_ontology  \
# 0                     carcinoma     Cell line                   BTO:0000018
# 1                     carcinoma     Cell line                   BTO:0006204
# 2                rhabdoid tumor     Cell line                   BTO:0002586
# 3                     carcinoma     Cell line                   BTO:0002398
# 4                     carcinoma     Cell line                   BTO:0002207
# ...                         ...           ...                           ...
# 9994           neuroepithelioma     Cell line                   BTO:0002914
# 9995                  carcinoma     Cell line                   BTO:0001248
# 9996  renal cell adenocarcinoma     Cell line                   BTO:0003846
# 9997  colorectal adenocarcinoma     Cell line                   BTO:0000391
# 9998                        NaN  primary cell                   BTO:0000099
#
#                  tissue_brenda_term  \
# 0                        A-549 cell
# 1                       Caki-2 cell
# 2                        G-401 cell
# 3     prostate epithelium cell line
# 4                     NCI-H460 cell
# ...                             ...
# 9994                   SK-N-MC cell
# 9995                     T-47D cell
# 9996                      ACHN cell
# 9997                     DLD-1 cell
# 9998                      astrocyte
#
#                                              tissue_url  \
# 0        https://www.atcc.org/products/all/CCL-185.aspx
# 1         https://www.atcc.org/products/all/HTB-47.aspx
# 2       https://www.atcc.org/Products/All/CRL-1441.aspx
# 3       https://www.atcc.org/products/all/CRL-1740.aspx
# 4        https://www.atcc.org/Products/All/HTB-177.aspx
# ...                                                 ...
# 9994      https://www.atcc.org/products/all/HTB-10.aspx
# 9995     https://www.atcc.org/products/all/HTB-133.aspx
# 9996    https://www.atcc.org/products/all/CRL-1611.aspx
# 9997     https://www.atcc.org/products/all/CCL-221.aspx
# 9998  https://www.encodeproject.org/experiments/ENCS...
#
#                           assay_label  source
# 0     Topologically Associated Domain  FANTOM
# 1     Topologically Associated Domain  FANTOM
# 2     Topologically Associated Domain  FANTOM
# 3     Topologically Associated Domain  FANTOM
# 4     Topologically Associated Domain  FANTOM
# ...                               ...     ...
# 9994  Topologically Associated Domain  FANTOM
# 9995  Topologically Associated Domain  FANTOM
# 9996  Topologically Associated Domain  FANTOM
# 9997  Topologically Associated Domain  FANTOM
# 9998  Topologically Associated Domain  FANTOM
#
# [9999 rows x 22 columns]

# %% [markdown]
# ## Filter unlinked enhnacers
#
# get the ones not in enh_gene_links table. They will be many because the sample fiie is tiny

# %%
unlinked = enhs[~enhs.index.isin(agg_table['enhancer'])]
unlinked = unlinked.merge(enh_source, how="left", left_on="enhancer", right_on="enhancer")
unlinked
# Out:
#                chr      start        end  source
# enhancer
# 2             chr1  100104444  100104686  FANTOM
# 3             chr1  100113534  100114036  FANTOM
# 4             chr1  100138206  100138591  FANTOM
# 5             chr1  100138994  100139323  FANTOM
# 6             chr1  100140321  100140582  FANTOM
# ...            ...        ...        ...     ...
# EH37E1054335  chrY    9992408    9992710  ENCODE
# EH37E1054336  chrY    9992720    9992792  ENCODE
# EH37E1054337  chrY    9992794    9992905  ENCODE
# EH37E1054338  chrY    9993122    9993334  ENCODE
# EH37E1054339  chrY    9993754    9993946  ENCODE
#
# [1085499 rows x 4 columns]

# %% [markdown]
# ## Concat the 2, many NaNs
#
# Idealy you can do outer join but if not interested in unlinked enhancers the n

# %%
all_enhs = pd.concat([agg_table, unlinked])
all_enhs

# %% [markdown]
# ## Save the files

# %%
agg_table.to_json("../../annoq-data/enhancer/test-out.json", orient="records", indent=2)

# %% [markdown]
# ## Load the sample annoq before(wgsa) and after(functions)

# %%
wgsa_anno =  pd.read_csv("../../annoq-data/slim-hrc/chr21.vcf", sep='\t')
all_anno =  pd.read_csv("../../annoq-data/slim-hrc-res/chr21.vcf", sep='\t')
all_anno
# Out:
#    chr       pos ref alt ANNOVAR_ensembl_Effect ANNOVAR_ensembl_Transcript_ID  \
# 0   21  15442715   T   A             intergenic                             .
# 1   21   9527214   T   A             intergenic                             .
# 2   21   9527233   T   A             intergenic                             .
# 3   21   9527233   T   C             intergenic                             .
# 4   21   9527242   A   G             intergenic                             .
# 5   21  15442714   T   G             intergenic                             .
#
#   ANNOVAR_ensembl_Gene_ID      ANNOVAR_ensembl_Closest_gene(intergenic_only)  \
# 0                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
# 1                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
# 2                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
# 3                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
# 4                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
# 5                       .  NONE:NONE(dist=NONE),ENSG00000238411:ENST00000...
#
#   ANNOVAR_ensembl_HGVSc ANNOVAR_ensembl_HGVSp  ...  \
# 0                     .                     .  ...
# 1                     .                     .  ...
# 2                     .                     .  ...
# 3                     .                     .  ...
# 4                     .                     .  ...
# 5                     .                     .  ...
#
#   enhancer_linked_PANTHER_GO_SLIM_molecular_function_list  \
# 0  triglyceride lipase activity;phospholipase act...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  triglyceride lipase activity;phospholipase act...
#
#   enhancer_linked_PANTHER_GO_SLIM_molecular_function_list_id  \
# 0                              GO:0004806;GO:0004620
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                              GO:0004806;GO:0004620
#
#   enhancer_linked_PANTHER_GO_SLIM_biological_process_list  \
# 0  triglyceride metabolic process;acylglycerol ca...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  triglyceride metabolic process;acylglycerol ca...
#
#   enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id  \
# 0                   GO:0006633;GO:0006641;GO:0046464
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                   GO:0006633;GO:0006641;GO:0046464
#
#   enhancer_linked_PANTHER_GO_SLIM_cellular_component_list  \
# 0                                extracellular space
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                extracellular space
#
#   enhancer_linked_PANTHER_GO_SLIM_cellular_component_list_id  \
# 0                                         GO:0005615
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                         GO:0005615
#
#                enhancer_linked_REACTOME_pathway_list  \
# 0  Phospholipid metabolism;Synthesis of PA;Metabo...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  Phospholipid metabolism;Synthesis of PA;Metabo...
#
#             enhancer_linked_REACTOME_pathway_list_id  \
# 0  R-HSA-556833;R-HSA-1430728;R-HSA-1483206;R-HSA...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  R-HSA-556833;R-HSA-1430728;R-HSA-1483206;R-HSA...
#
#   enhancer_linked_PANTHER_pathway_list enhancer_linked_PANTHER_pathway_list_id
# 0                                    .                                       .
# 1                                    .                                       .
# 2                                    .                                       .
# 3                                    .                                       .
# 4                                    .                                       .
# 5                                    .                                       .
#
# [6 rows x 629 columns]

# %% [markdown]
# ## How many annotations added

# %%
len(all_anno.columns) - len(wgsa_anno.columns)
# Out:
# 181

# %%
all_anno.iloc[0:,448:]
# Out:
#   flanking_0_GO_molecular_function_complete_list  \
# 0                                              .
# 1                                              .
# 2                                              .
# 3                                              .
# 4                                              .
# 5                                              .
#
#   flanking_0_GO_molecular_function_complete_list_id  \
# 0                                                 .
# 1                                                 .
# 2                                                 .
# 3                                                 .
# 4                                                 .
# 5                                                 .
#
#   flanking_0_GO_biological_process_complete_list  \
# 0                                              .
# 1                                              .
# 2                                              .
# 3                                              .
# 4                                              .
# 5                                              .
#
#   flanking_0_GO_biological_process_complete_list_id  \
# 0                                                 .
# 1                                                 .
# 2                                                 .
# 3                                                 .
# 4                                                 .
# 5                                                 .
#
#   flanking_0_GO_cellular_component_complete_list  \
# 0                                              .
# 1                                              .
# 2                                              .
# 3                                              .
# 4                                              .
# 5                                              .
#
#   flanking_0_GO_cellular_component_complete_list_id  \
# 0                                                 .
# 1                                                 .
# 2                                                 .
# 3                                                 .
# 4                                                 .
# 5                                                 .
#
#   flanking_0_PANTHER_GO_SLIM_molecular_function_list  \
# 0                                                  .
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                                  .
#
#   flanking_0_PANTHER_GO_SLIM_molecular_function_list_id  \
# 0                                                  .
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                                  .
#
#   flanking_0_PANTHER_GO_SLIM_biological_process_list  \
# 0                                                  .
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                                  .
#
#   flanking_0_PANTHER_GO_SLIM_biological_process_list_id  ...  \
# 0                                                  .     ...
# 1                                                  .     ...
# 2                                                  .     ...
# 3                                                  .     ...
# 4                                                  .     ...
# 5                                                  .     ...
#
#   enhancer_linked_PANTHER_GO_SLIM_molecular_function_list  \
# 0  triglyceride lipase activity;phospholipase act...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  triglyceride lipase activity;phospholipase act...
#
#   enhancer_linked_PANTHER_GO_SLIM_molecular_function_list_id  \
# 0                              GO:0004806;GO:0004620
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                              GO:0004806;GO:0004620
#
#   enhancer_linked_PANTHER_GO_SLIM_biological_process_list  \
# 0  triglyceride metabolic process;acylglycerol ca...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  triglyceride metabolic process;acylglycerol ca...
#
#   enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id  \
# 0                   GO:0006633;GO:0006641;GO:0046464
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                   GO:0006633;GO:0006641;GO:0046464
#
#   enhancer_linked_PANTHER_GO_SLIM_cellular_component_list  \
# 0                                extracellular space
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                extracellular space
#
#   enhancer_linked_PANTHER_GO_SLIM_cellular_component_list_id  \
# 0                                         GO:0005615
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5                                         GO:0005615
#
#                enhancer_linked_REACTOME_pathway_list  \
# 0  Phospholipid metabolism;Synthesis of PA;Metabo...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  Phospholipid metabolism;Synthesis of PA;Metabo...
#
#             enhancer_linked_REACTOME_pathway_list_id  \
# 0  R-HSA-556833;R-HSA-1430728;R-HSA-1483206;R-HSA...
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4                                                  .
# 5  R-HSA-556833;R-HSA-1430728;R-HSA-1483206;R-HSA...
#
#   enhancer_linked_PANTHER_pathway_list enhancer_linked_PANTHER_pathway_list_id
# 0                                    .                                       .
# 1                                    .                                       .
# 2                                    .                                       .
# 3                                    .                                       .
# 4                                    .                                       .
# 5                                    .                                       .
#
# [6 rows x 181 columns]

# %%
all_anno.loc[0,'enhancer_linked_PANTHER_GO_SLIM_biological_process_list_id']
# Out:
# 'GO:0006633;GO:0006641;GO:0046464'
